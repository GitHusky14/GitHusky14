# %%
conda install ipython jupyter
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - ipython
#     - jupyter
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyter-1.0.0              |   py36h5fab9bb_6           6 KB  conda-forge
#     jupyter_console-6.4.0      |     pyhd8ed1ab_0          22 KB  conda-forge
#     prompt-toolkit-3.0.26      |     pyha770c72_0         250 KB  conda-forge
#     prompt_toolkit-3.0.26      |       hd8ed1ab_0           5 KB  conda-forge
#     qtconsole-5.2.2            |     pyhd8ed1ab_1           5 KB  conda-forge
#     qtconsole-base-5.2.2       |     pyhd8ed1ab_1          90 KB  conda-forge
# ...

# %%
import numpy as np

# %%
conda install -c numba numba
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - numba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     llvmlite-0.36.0            |   py36hf484d3e_0        19.8 MB  numba
#     numba-0.53.1               |np1.11py3.6h04863e7_g97fe221b3_0         3.6 MB  numba
#     ------------------------------------------------------------
#                                            Total:        23.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   llvmlite           numba/linux-64::llvmlite-0.36.0-py36hf484d3e_0
#   numba              numba/linux-64::numba-0.53.1-np1.11py3.6h04863e7_g97fe221b3_0
#
#
#
# ...

# %%
conda install -c conda-forge librosa
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - librosa
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.2.0                  |       h9c3ff4c_2         5.4 MB  conda-forge
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     audioread-2.1.9            |   py36h5fab9bb_0          32 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     ffmpeg-4.4.1               |       h6987444_0        10.0 MB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
# ...

# %%
import librosa
